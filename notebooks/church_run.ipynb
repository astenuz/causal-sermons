# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# changing the working dir to the project's dir

# %%
import os

project_path = "/content/drive/MyDrive/ds/causal-sermons"
os.chdir(project_path)

# %% [markdown]
# Adding src to pythonpath

# %%
import sys
import os
from pathlib import Path

# Get the current working directory (the directory where your notebook is located)
current_dir = Path(os.getcwd())

# Add the current directory to the Python path
sys.path.append(str(current_dir/"src"))

# %%
# !pip install -r requirements.txt

# %% [markdown]
# # Training the model with some data

# %% [markdown]
# Process church data

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
# reading sermon data
sermons = pd.read_pickle('./data/sermons/raw/sermoncentral.pkl')

# %%
sermons.head()

# %%
sermons.shape[0]

# %%
sns.displot(x='overall_political_sermons', data=sermons)

# %%
import pandas as pd
from causal_sermons.causal_bert import CausalBertWrapper

# %%
df = pd.read_csv('./data/testdata.csv')

cb = CausalBertWrapper(batch_size=32,                       # init a model wrapper
    g_weight=0.1, Q_weight=0.1, mlm_weight=1)

cb.train(df['text'], df['C'], df['T'], df['Y'], epochs=4)  # train the model

# %%
cb.ATE(df['C'], df['text'], platt_scaling=True)
